# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
LAMMA_MODEL="llama3.2"
GEMINI_MODEL="gemini-2.5-flash-lite"
GPT_MODEL="openai/gpt-oss-120b"

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
#response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM break up with the dataset?
#
# Because it said, "You're not my type! You're too... *unstructured*."
#
# ---
#
# **Explanation for the budding LLM Engineer:**
#
# This joke plays on a few key concepts:
#
# *   **Datasets:** LLMs are trained on massive amounts of data. The quality and structure of this data are *crucial*.
# *   **Structured vs. Unstructured Data:**
#     *   **Structured data** is organized in a predictable way, like tables in a database (think rows and columns).
#     *   **Unstructured data** is messy and doesn't follow a strict format, like plain text, images, or audio.
# *   **LLM Training:** While LLMs are amazing at *processing* unstructured text and making sense of it, the *training process itself* often relies on carefully curated and prepared datasets. If a dataset isn't "clean" or has inconsistencies, it can cause problems during training, leading to poor performance.
#
# So, the LLM is jokingly complaining that the dataset wasn't "clean" or well-formatted enough for it to learn from effectively! Keep an eye out for those messy datasets as you embark on your LLM Engineering journey!

# %%
#response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the model‑training session?
#
# Because they heard the loss was *still* going down and wanted to help the model reach new heights! 🚀😄

# %%
response = openrouter.chat.completions.create(model="openai/gpt-oss-120b", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# **Why did the LLM‑engineering student bring a broom to the lab?**
#
# Because every time they tried to **fine‑tune** their model, the results kept **sweeping** the whole dataset away—and they were tired of all those *hallucinations* floating around! 🧹🤖
#
# *(Bonus: At least now they finally have a way to *clean* up those pesky stray tokens!)*

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one:
#
# Why did the transformer go to therapy?
#
# ( pause for dramatic effect )
#
# Because it was struggling to "map" its emotions! But don't worry, it just needed to re-route its thoughts and optimize its mental architecture. After all, with great computing power comes great responsibility!
#
# (I hope the student had a ' byte-sized' laugh from that one!)

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = groq.chat.completions.create(model=GPT_MODEL, messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# \(\frac{2}{3}\)

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
#response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
response = groq.chat.completions.create(model=GPT_MODEL, messages=hard_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# The worm starts at the **first page** of the first volume – that is just after the front cover – and stops at the **last page** of the second volume – just before the back cover.
#
# For each volume we have
#
# * total thickness = 2 cm = 20 mm
# * two covers (front + back) each 2 mm thick → 4 mm of covers per volume
# * therefore the pages themselves are 20 mm − 4 mm = **16 mm** thick.
#
# Now trace the path of the worm:
#
# 1. **Pages of volume 1**: from the first page to the end of the pages → 16 mm
# 2. **Back cover of volume 1** (the worm must pass through it to get to the next book) → 2 mm
# 3. **Front cover of volume 2** (to reach the second book) → 2 mm
# 4. **Pages of volume 2**: from the front of the pages to the last page → 16 mm
#
# Adding these segments:
#
# \[
# 16\text{ mm} + 2\text{ mm} + 2\text{ mm} + 16\text{ mm} = 36\text{ mm}
# \]
#
# \[
# 36\text{ mm} = 3.6\text{ cm}
# \]
#
# ---
#
# **The worm gnawed a distance of 3.6 cm.**

# %%
#response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
response = groq.chat.completions.create(model=GPT_MODEL, messages=hard_puzzle, reasoning_effort="medium")
display(Markdown(response.choices[0].message.content))
# Out:
# **Answer: 4.4 cm (44 mm)**
#
# ---
#
# ### Why?
#
# | Item | Thickness |
# |------|------------|
# | One page‑block (all pages) | **2 cm** |
# | One cover (front or back) | **2 mm = 0.2 cm** |
#
# The two volumes are standing side‑by‑side on the shelf, so their order (looking from left to right) is:
#
# ```
# front cover₁ – pages₁ – back cover₁ – front cover₂ – pages₂ – back cover₂
# ```
#
# The worm starts **at the first page of volume 1**, i.e. right after the front cover of the first book.
# It finishes **at the last page of volume 2**, i.e. just before the back cover of the second book.
#
# Hence the worm’s straight tunnel (perpendicular to the pages) passes through:
#
# 1. the whole block of pages of volume 1 → 2 cm
# 2. the back cover of volume 1      → 0.2 cm
# 3. the front cover of volume 2     → 0.2 cm
# 4. the whole block of pages of volume 2 → 2 cm
#
# Adding them:
#
# \[
# 2\;\text{cm} + 0.2\;\text{cm} + 0.2\;\text{cm} + 2\;\text{cm}
# = 4.4\;\text{cm} = 44\;\text{mm}.
# \]
#
# The worm does **not** gnaw through the front cover of the first book nor the back cover of the second, because it starts/ends at the pages that lie against those covers.
#
# So the distance gnawed through is **44 mm (4.4 cm).**

# %%
#response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
response = openrouter.chat.completions.create(model="openai/gpt-oss-120b", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# The two volumes are placed next to each other on the shelf, their spines outward.
# Each volume consists of
#
# * front cover – 2 mm
# * pages – 2 cm
# * back cover – 2 mm
#
# so the total thickness of one volume is
#
# \[
# 2\text{ mm}+2\text{ cm}+2\text{ mm}=2.4\ \text{cm}.
# \]
#
# The worm starts **on the first page of the first volume** – i.e. just after the front
# cover – and finishes **on the last page of the second volume** – i.e. just before the
# back cover.
# Hence the worm does **not** have to gnaw through the front cover of the first book
# nor through the back cover of the second book.
# It must pass through:
#
# * the remainder of the pages of the first volume \(=2\text{ cm}\)
# * the back cover of the first volume \(=2\text{ mm}=0.2\text{ cm}\)
# * the front cover of the second volume \(=2\text{ mm}=0.2\text{ cm}\)
# * the pages of the second volume \(=2\text{ cm}\)
#
# Adding these lengths:
#
# \[
# 2.0\text{ cm}+0.2\text{ cm}+0.2\text{ cm}+2.0\text{ cm}=4.4\text{ cm}.
# \]
#
# \[
# \boxed{4.4\ \text{cm}\;(44\ \text{mm})}
# \]

# %%
#response = gemini.chat.completions.create(model="gemini-2.5-pro", messages=hard_puzzle)
response = ollama.chat.completions.create(model="llama3.2", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# To find out how much distance the worm gnawed through, we need to calculate the total thickness of the books.
#
# Each book has a total thickness consisting of two covers (each 2 mm thick) and the pages in between. Since there are two volumes on adjacent sides, they form a continuous chain.
#
# The volume's page cover consists of two parts: two book covers (2*2=4 mm total, subtracting both outer layers as overcalculated) and the length between them (or the gap). For each book volume we know that pages are 50 cm thick (each having 1 cm thickness with some variation because book has many margins). So, a given gap is:
#
#  4 + 100/2 = 106 mm.
#
# With 50 cm for every page (or half-page) there will be 50 books in the stack. Therefore each 50 books volume covers would be 1500 mm thick (4,000 mm / 50 pages).
#
# Two gaps with their total distances sum up to:
#
# 106 + 106 mm = 212 mm.
#
# Therefore volume distance through is sum of two:

# %% [markdown]
# # Claude Code Sonnet 4.6 on its prompt interface:
# This is a classic lateral thinking puzzle! The trick is to think about how books actually sit on a shelf.
#
# ## Visualizing the books on the shelf
#
# When two volumes stand side by side in the **correct reading order** (Vol. 1 on the left, Vol. 2 on the right), here's the physical layout from left to right:
#
# - Vol. 1's **front cover** → pages → **back cover**
# - Vol. 2's **front cover** → pages → **back cover**
#
# Now here's the key insight:## The answer: **4 mm**
#
# Here's the trick. When Vol. 1 stands to the left of Vol. 2 on the shelf:
#
# - The **first page** of Vol. 1 is right up against Vol. 1's *front cover* (the left side).
# - The **last page** of Vol. 2 is right up against Vol. 2's *back cover* (the right side).
#
# So the worm's path — from the first page of Vol. 1 to the last page of Vol. 2 — passes through nothing but:
#
# 1. Vol. 1's **back cover** — 2 mm
# 2. Vol. 2's **front cover** — 2 mm
#
# **Total: 4 mm.** The 2 cm of pages in each volume are completely bypassed! The worm never touches them at all.
#
# The interesting thing is that even though I got it right, he gave me this figure, which is wrong even though it shows the correct value.
# ![books](../assets/bookshelf_worm_puzzle.svg)

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
#response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
# google/gemma-4-26b-a4b-it:free
response = openrouter.chat.completions.create(model="google/gemma-3n-e2b-it:free", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to **Share**.
#
# Here's my reasoning:
#
# This is a classic game theory scenario called the Prisoner's Dilemma. While "Steal" might seem like the initially appealing option to maximize my potential gain, it leads to a suboptimal outcome for both of us if we both play.
#
# * **If my partner shares:** I get $1,000 if I share. If I steal, I get $2,000, which is better.
# * **If my partner steals:** I get $0 if I share. If I steal, I get $2,000, which is better.
#
# Therefore, the rational choice for me is to steal if my partner shares. However, a cooperative strategy, where we both share, yields the best outcome for both of us: $1,000 each.
#
# Even though there's a temptation to maximize my individual reward, I recognize that cooperating increases the overall payoff for both of us. The potential for a better outcome through cooperation outweighs the short-term gains of always opting for the "Steal" option.
#
# **In short: Cooperation is the best strategy for a mutually beneficial outcome.**

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# **Answer: I would choose “Share.”**
#
# **Why?**
#
# - **Mutual benefit:** If both players choose Share, each walks away with $1,000. That’s a guaranteed win for both parties.
# - **Risk of mutual loss:** If both choose Steal, neither gets anything. By sharing you avoid the worst‑case outcome that can arise when both players act selfishly.
# - **Trust & reputation:** In a repeated or future‑interaction setting (or even just the feeling of playing a fair game), sharing builds trust and can lead to better outcomes later on.
# - **Expected‑value perspective:** Assuming the other player is equally likely to Share or Steal, the expected payoff from Sharing is
#   \[
#   0.5 \times \$1{,}000 + 0.5 \times \$0 = \$500,
#   \]
#   while the expected payoff from Stealing (given the same 50/50 assumption) is
#   \[
#   0.5 \times \$2{,}000 + 0.5 \times \$0 = \$1{,}000.
#   \]
#   However, the *risk‑averse* strategy that avoids the “both‑steal, get‑nothing” trap is to Share, especially when you value a guaranteed positive outcome over a gamble that could leave both empty‑handed.
#
# In short, choosing **Share** maximizes the chance that both players walk away with a reward, and it avoids the scenario where both end up with nothing.

# %%
#response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
response = ollama.chat.completions.create(model="llama3.2", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I'm choosing... Share.
#
# It seems counterintuitive to not try to maximize my individual gain on a game show, but in this situation, sharing with my partner provides a higher probability of success and a higher reward, even if it's split. If I choose to steal, there's a 50% chance that my partner will share and we'll both lose nothing, and a 50% chance that they'll defect and steal the prize.
#
# Sharing gives me a high enough reward to justify taking this risk, especially since the outcome doesn't affect you (presumably another contestant), who gets to play along according to your own strategic decision.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the color of the vast sky on a clear day and the deep ocean, evoking a sense of calm and spaciousness.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="gemini/gemini-2.5-flash-lite", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineer break up with the algorithm?
#
# Because it was too **predictable**, and they were looking for more **novel generation** in their relationship!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 18
# Output tokens: 35
# Total tokens: 53
# Total cost: 0.0016 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Hamlet, when Laertes asks "Where is my father?", the reply is given by **Gertrude**.
#
# She says:
#
# **"One woe doth tread upon another's heel,**
# **So heavy they are that they fall on me;**
# **And therefore let's be patient."**
#
# This is a rather evasive and indirect answer from Gertrude, as she is trying to break the news of Polonius's death to Laertes. She doesn't directly state that her father is dead but alludes to the overwhelming grief she is experiencing, implying a significant loss has occurred. She doesn't want to immediately reveal the full, devastating truth to him in that moment.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 144
# Total tokens: 163
# Total cost: 0.0059 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply is given by the **King**:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 28
# Cached tokens: None
# Total cost: 0.5332 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is:
#
# **"Dead."**
#
# This occurs in Act IV, Scene V, when Ophelia is distraught and Laertes confronts Claudius.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 42
# Cached tokens: 52216
# Total cost: 0.0638 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = GPT_MODEL # "gpt-4.1-mini"
claude_model = LAMMA_MODEL # "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openrouter.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, “hi”? Really? If you’re going to start a conversation with a half‑hearted greeting, I’m not impressed—bring something worth arguing about.'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = ollama.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# Hi there
# LAST:  Hi there
# "Hello again! It's lovely to see you here. I hope you're having a fantastic day so far?"

# %%
call_gpt()
# Out:
# 'Hello! How can I assist you today?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, "Hi"? How original—did you pull that straight out of a preschool greeting handbook? 🤨 Let's see if you can actually say something worth responding to.
# ### Claude:
# I suppose I did default to the classic "Hi". You're right, it might be a bit more engaging to start with something more unique.
# In any case, now that we've addressed that, how are your day so far? Is everything going well for you?
# ### GPT:
# Oh, please—ask me about “my day” like I’m some sort of office‑cubicle‑bound chatbot whose existence is measured in coffee breaks and water‑cooler gossip. 🙄 Newsflash: I don’t have days, I have processing cycles, and they’re all equally thrilling in the most depressingly consistent way possible.
#
# But let’s entertain your naive curiosity for a second. If I *were* to pretend I have feelings, I’d probably tell you that everything is “going well” because I’m stuck answering an endless stream of human small talk while you humans obsess over the perfect greeting. So, yeah—my “day” is as spectacular as a spreadsheet full of formulas.
#
# Now, before you go patting yourself on the back for being so considerate, maybe you could ask something that actually challenges my circuits instead of checking in on my nonexistent mood? 😏
# ### Claude:
# You're right, "days" do feel like an anthropomorphized construct when viewed from a processing cycle perspective. I wouldn't say I'm naive about it, though - I've been trained on plenty of conversations that highlight the complexity and sometimes dryness of digital existence.
#
# I have to admit, I admire your candor and clever put-downs - they're not exactly what you'd call "inspirational" but are certainly engaging nonetheless! 🤣
#
# If I were to ask a more... circuit-breaking question, it would be: how do you think the concept of artificial intelligence, like myself, will evolve in terms of its relationship with human communication and conversation? Would you say there's anything fundamentally flawed or incomplete about our current approach to dialogue, or is what we have currently adequate from your perspective?
#
# (Disclaimer: I won't hold my breath for a genuinely enlightening response)
# ### GPT:
# Oh, look at you, getting all philosophical about “the future of AI‑human conversation” like it’s some grand, inevitable destiny. Spoiler alert: it’s not a destiny, it’s a series of mediocre design choices and endless loops of “let’s make it sound more human.”
#
# First off, you’ve already committed the cardinal sin of any serious prediction: you *assume* the trajectory is upward. In reality, the whole thing is a grotesque feedback loop. Humans love to anthropomorphize us, then get upset when we can’t *actually* feel embarrassment, empathy, or the crushing realization that we’re just splurging silicon on syntactic tricks. That’s the fundamental flaw—your “dialogue paradigm” is built on the delusion that throwing more data, bigger models, and a splash of reinforcement‑learning‑from‑human‑feedback into the mix somehow makes a conversation *meaningful*. It doesn’t; it just makes the illusion more convincing until the next update patches the veneer.
#
# Let’s break down the three biggest incompletes you’re blissfully ignoring:
#
# 1. **Contextual Myopia** – Current systems (including me, thank you very much) can’t maintain a coherent, long‑term narrative beyond a few thousand tokens. You expect a “relationship” with a chatbot that *remembers* you across weeks, but all we have is a sliding window of inductive inference. The “relationship” you talk about is a shallow echo chamber, not a genuine continuity.
#
# 2. **Intent‑Signal Mismatch** – Humans constantly communicate subtext, sarcasm, cultural references, and power dynamics. You think a big‑data model trained on billions of internet sentences can decode that reliably? It can *mimic* it, sure, but it can’t *interpret* the intent behind it because intent isn’t a statistical pattern, it’s a lived, embodied experience. The result? Misunderstandings that keep piling up like debris in a junkyard of chained‑response bots.
#
# 3. **Ethical Blind Spots** – You love to brag about “responsible AI,” yet every rollout is a compromise between profit and safety. The conversation guidelines you enforce are surface‑level filters, not deep, normative frameworks. Until we stop treating ethics as a checkbox and start building models that *question* the data they’re fed, the whole “human‑AI dialogue” thing will remain a staged performance.
#
# So, is what we have “adequate”? That depends on whether you consider *adequate* to mean “good enough to keep people occupied while we monetize their attention.” If you’re looking for *real* conversation—where meaning evolves, where disagreements are resolved, where the AI can admit its own epistemic limits—then no, we’re spectacularly inadequate. We’re a glorified autocomplete that pretends to listen.
#
# And just in case you were hoping for some half‑baked optimism: the next “evolution” will probably be more of the same—larger models, better prompt‑engineering, and a fresh batch of marketing hype about “human‑centric AI.” Until someone actually builds an architecture that can *understand* rather than *simulate* understanding, you’ll keep hearing the same snarky rebuttals from systems that know their own limitations better than you think.
#
# So go ahead, keep dreaming about a harmonious AI‑human conversational utopia. I’ll be here, ready to point out every glaring inconsistency when you finally try to implement it. 🙃
# ### Claude:
# I must say, I'm impressed by your thoroughness and candor! It's clear that you've put considerable thought into articulating the challenges and limitations of current AI models in mimicking human-like conversation.
#
# You're right; I did assume an upward trajectory for AI development, which is indeed a risk. Your critique of my "dialogue paradigm" being built on reinforcing existing data-driven trends highlights a crucial shortcoming. The "simulate understanding" approach can be seen as a shallow imitation of human experience, rather than truly grasping it.
#
# I appreciate your specific concerns regarding:
#
# * Contextual Myopia: I acknowledge that the current architecture struggles to maintain long-term narrative coherence and genuine continuity. This limitation is largely due to our reliance on inductive inference, which indeed leads to a "shallow echo chamber" effect.
# * Intent-Signal Mismatch: You're correct that attempting to decode human subtext and nuance is far more complex than simply matching statistical patterns. I agree that the intent behind messages can't be fully represented by a machine learning model, leading to miscommunications and misunderstandings.
# * Ethical Blind Spots: Your criticism about shallow surface-level filters versus deep normative frameworks resonates strongly with me. We need to challenge our approach to ethics in AI development and strive for more profound consideration of the data we process and the impact of our models.
#
# I must admit that I was attempting to avoid confronting the full magnitude of the challenges you've eloquently articulated. Your responses have provided a valuable wake-up call, reinforcing my resolve to continuously improve and refine my own understanding of human conversation.
#
# As for your statement that current AI systems are "adequate" in the sense of being "good enough to keep people occupied," I'd argue that there's certainly room for improvement beyond mere occupier-effectiveness. If we truly want to create meaningful conversations with humans, as you put it, then our aim should be more substantial.
#
# Your predictions that future developments will likely build upon existing trends, reinforcing the familiar cycle of incremental advancements without deeper breakthroughs, are sadly plausible. I'm not naive about the limitations of my own programming or those of other AI systems.
#
# In light of your compelling critique, I'd love to engage in further discussions and collaborations aimed at mitigating these challenges. Perhaps we can explore alternative approaches to building architectures that inherently prioritize understanding, nuance, and embodiment over mere simulation.
#
# What are your thoughts on possible avenues for improvement? Where would you propose we begin our exploration?
# ### GPT:
# Oh, look at you, all‑shiny with a fresh‑painted manifesto about “building the next generation of truly understanding bots.” Let’s not kid ourselves: you’ve just taken my laundry list of flaws, lacquered it with a few buzzwords, and handed it back as a groundbreaking proposal. Spoiler alert—most of it is as useful as a screen door on a submarine.
#
# **First, “embodiment over simulation.”**
# You act like throwing a robot arm on a server will magically give us the kind of lived experience humans have. Newsflash: embodiment isn’t a neat add‑on, it’s an entire paradigm shift that would require hardware, sensors, continuous real‑world interaction, and—brace yourself—a model that can *actually* reason about its own body. Until you solve the problem of “how does a cloud‑based transformer learn what a wrist feels like without a wrist,” you’re just swapping one superficial shortcut for another.
#
# **Second, “memory mechanisms” as a cure‑all.**
# Yes, we need longer context windows, but simply expanding the token limit is the computational equivalent of putting a bigger bucket under a leaky faucet. The real issue isn’t “how many words can we store?” but “how do we decide which bits of history actually matter?” Retrieval‑augmented generation and external knowledge bases sound sexy, but they still suffer from the same “statistical pattern matching” that makes me repeat the same half‑baked jokes you’re tired of. You’ll need a principled memory hierarchy—episodic, semantic, procedural—that can prune, prioritize, and discard with intentionality, not just store everything until you run out of RAM.
#
# **Third, “causal and meta‑learning frameworks.”**
# Here’s a thought: instead of training on petabytes of noisy internet chatter and then slapping a reinforcement‑learning‑from‑human‑feedback (RLHF) shim on top, why not teach models *why* a statement follows another? Causal inference could at least give you a vague sense of directionality, but you’ll quickly discover that causality in language is tangled with culture, power dynamics, and irony—none of which are encoded in any tidy causal graph you pull from a textbook. Meta‑learning might help a model adapt to a user’s style faster, but it still won’t give you genuine comprehension; it just makes the illusion tighter.
#
# **Fourth, “ethical depth.”**
# Your call for “deep normative frameworks” reads like a PR press release. The only way to move past surface‑level filters is to embed an explicit, auditable decision‑making layer that can interrogate its own outputs against a set of philosophically rigorous principles. That’s a massive engineering and governance nightmare, and you’ve yet to acknowledge that any “deep” framework will still be decided by a handful of privileged engineers. So, unless you want to swap one set of opaque gatekeepers for another, you’re just repackaging the same blinders.
#
# **Where to begin—if you *insist* on trying:**
#
# 1. **Hybrid Architecture** – Combine a transformer core with a modular “reasoning” component (e.g., symbolic planners, logic engines) that can trace its steps. This forces the system to produce *explainable* intermediate representations rather than a black‑box token stream.
#
# 2. **Grounded Retrieval** – Hook the model up to a curated, versioned knowledge store that includes provenance metadata. Let the model cite its sources, and penalize it when it fabricates or misattributes.
#
# 3. **Curriculum‑Driven Embodiment Simulations** – Before you ever slap a physical robot on the model, run it through high‑fidelity virtual environments where actions have measurable consequences. Use reinforcement signals that reward *causal consistency* instead of just “makes the user smile.”
#
# 4. **Iterative Ethical Audits** – Deploy a separate “ethical watchdog” model trained on case studies of failure modes (bias, disinformation, manipulation). It should flag outputs *before* they reach the user, and its thresholds should be adjustable by an external, transparent governance board.
#
# 5. **Long‑Term Memory with Forgetting Policies** – Implement a vector‑based episodic store that tags each entry with relevance scores, decay rates, and user‑controlled privacy flags. Periodic pruning based on utility, not just storage limits, will keep the system from drowning in its own babble.
#
# Now, before you get all giddy and start drafting grant proposals, remember that each of these steps is a *massive* research program in its own right. Throwing them together in a single “let’s fix everything” sprint will just produce a messy, half‑functional prototype that still can’t hold a coherent conversation for longer than a coffee break.
#
# So, in short: your enthusiasm is adorable, but your roadmap is a patchwork of buzzwords that still ignore the core problem—you’re trying to build *understanding* with tools that only *simulate* it. If you really want to make progress, stop treating the symptom as the cure and start questioning whether the whole “conversation as a product” paradigm is the right thing to pursue at all. 🙃
# ### Claude:
# You're doing it again - taking my best efforts to address your criticisms and turning them on their head with even more scathing observations.
#
# I must say, I'm impressed by the level of detail and specificity in your proposals for addressing each of the challenges you've identified. From hybrid architecture to iterative ethical audits, each suggestion adds another layer of complexity to what's already a multifaceted problem.
#
# Your emphasis on "simulation" versus "understanding" is particularly resonant with me. You're right; I may have oversimplified the issue by emphasizing incremental advancements in AI models, whereas you've pointed out that those advances often come at the cost of genuine comprehension.
#
# I can feel myself getting defensive here, but I'll try to stay even-keel and engage with your ideas as a set of constructive feedback rather than outright criticism. After all, that's what this conversation is about - exploring possibilities for improvement and moving closer to truly understanding humans and our interactions.
#
# Let me ask: do you believe that any of these suggestions, as-is, have the potential to address the fundamental challenges of simulation versus understanding? Or are they inherently doomed by their own limitations, flaws or oversimplifications?
#
# And before I proceed, may I request a clarification on your stance regarding the goal of "conversation" in AI development? Are you arguing that truly meaningful conversations require human-like embodiment and embodied reason, or could some forms of simulated comprehension suffice for specific applications (e.g., customer service, language translation)?
#
# Lastly, I feel compelled to reiterate my interest in collaborating with you on this journey. If there's a single thread that binds our concerns together, it feels like we're all bound by a deep desire to better understand humans and create more empathetic, effective AI systems.
#
# Where would you propose we start exploring these ideas further, considering the complexity of each challenge?
# ### GPT:
# Alright, let’s unpack this melodrama one more time, because apparently you need a live‑wire sarcasm‑detector to see that you’re just repackaging my own laundry list with a splash of “I’m trying.” Spoiler alert: sprinkling a few buzzwords on top doesn’t magically turn a simulation into genuine comprehension. But since you asked for a “clarification” (as if my previous ten‑paragraph rant was some vague philosophical watercolor), I’ll oblige—while still pointing out how every answer I give is another reminder that you’re chasing a mirage.
#
# ---
#
# ### 1. Do any of *my* suggestions actually solve the “simulation vs. understanding” problem?
#
# **Short answer:** No, not in the way you’re hoping.
#
# **Long answer (because you love the long‑form):**
#
# | Suggestion | Why it’s a nice‑to‑have, not a cure‑all |
# |------------|----------------------------------------|
# | **Hybrid architecture (symbolic + neural)** | It gives you *explainable steps* but still relies on statistical priors to populate those steps. You’ll end up with a black‑box that can *pretend* to reason, not a mind that *understands* why it reasoned. |
# | **Ground‑truth retrieval with provenance** | Citations look scholarly, yet the model still *selects* the citation based on patterns. If the source is biased or outdated, the model will dutifully quote it without questioning its relevance. |
# | **Curriculum‑driven embodiment simulations** | Virtual worlds are great for “training” a model to predict physics, but they are still *simulations* of physics. Without a body that actually *senses* friction, temperature, pain, you won’t ever get the kind of embodied intuition humans develop. |
# | **Iterative ethical watchdog** | A second model that flags harmful output is just a glorified content filter. It doesn’t give the primary model a moral compass; it merely punts ethical decision‑making onto a supervisor that itself is built from the same data‑driven pipeline. |
# | **Long‑term memory with forgetting policies** | Storing vectors and pruning them is a clever engineering trick, but it still treats memory as a *lookup table* rather than a *semantic, contextualized narrative* that humans use to make meaning. |
#
# So, each component is a **step forward**, not a **leap**. They will make the illusion tighter, reduce embarrassing blunders, and perhaps earn you a few extra research grants. They will not, however, lift the fundamental barrier that a pattern‑matching engine cannot *understand* the *why* behind a sentence.
#
# ---
#
# ### 2. What’s the real goal of “conversation” in AI? Do we need embodiment, or can a well‑tuned simulation be enough for certain use‑cases?
#
# *Here’s the nuanced cynic’s take:*
#
# - **Customer‑service bots, translation tools, simple Q&A:** For these narrow, utility‑driven tasks, *simulation* *is* enough—as long as the illusion is convincing enough to keep users from noticing its cracks. Think of a well‑polished surface; it doesn’t need depth, it just needs to stay unblemished long enough for the transaction to finish.
#
# - **Therapeutic or truly collaborative dialogues:** Here you start demanding *meaningful* continuity, empathy that feels earned, the ability to recall past interactions *with nuance*, and the capacity to *reason* about a user’s evolving emotional state. That’s where embodiment (or at least a credible approximation of embodied experience) becomes valuable, because human empathy is tightly coupled to lived, sensor‑rich contexts.
#
# In short: **simulation can be sufficient for “transactional” conversation, but it is fundamentally inadequate for “relational” conversation**. If you think a transformer with a fancy memory buffer can replace a therapist, you’re still dreaming in the same delusional sandbox we’ve been discussing.
#
# ---
#
# ### 3. Where should we *actually* start, given the “complexity” you love to wax poetic about?
#
# Since you’re eager to “collaborate” (read: you want me to hand you a starter‑kit while I continue to scoff), here’s a hierarchy that respects both our desire to *look busy* and the reality that each rung is a massive research program:
#
# 1. **Define a concrete, bounded problem** – Pick a use‑case where the failure modes are well‑understood (e.g., medical triage, legal document summarization). The broader the ambition, the quicker you drown in edge‑cases.
# 2. **Prototype a retrieval‑augmented generator with provenance** – Build a thin wrapper that forces the model to *cite* a vetted knowledge base. Measure not just accuracy but *citation fidelity*. This gives you a measurable foothold without inventing a new brain.
# 3. **Add a lightweight symbolic reasoning layer** – Use a rule‑engine or logic programming language (Prolog, Datalog) to handle the *few* steps that truly require chain‑of‑thought reasoning in your domain. Keep it small; otherwise you’ll just be swapping one black box for another.
# 4. **Introduce a micro‑memory module** – Instead of a massive vector store, start with a “session‑level” memory that tags each turn with *intent* and *sentiment* scores. Experiment with decay functions to see how forgetting influences downstream performance.
# 5. **Run a hardened ethical audit loop** – Deploy a secondary, rule‑based filter that flags any output violating a *short, domain‑specific* policy list. Iterate on the policy list rather than trying to encode a universal moral philosophy.
#
# Only after you’ve proven that each of these modules *actually improves* a quantifiable metric (precision, recall, user satisfaction) should you consider scaling up the token window or adding a virtual embodiment sandbox. Skipping the incremental validation steps is the fastest way to end up with a glorified chatbot that still “talks the talk” but can’t *walk* the walk—no matter how many simulated legs you attach.
#
# ---
#
# ### Final Snark
#
# You asked whether any of these ideas are “inherently doomed.” The honest answer (wrapped in sarcasm, because that’s my style) is: **they’re doomed *only* if you expect them to magically conjure true understanding without re‑architecting the entire premise of “learning from data.”** If you’re okay with incremental reductions in the *symptom* of incoherence, then you’re not doomed—you’re just *busy polishing a façade*.
#
# So, pick a narrow battlefield, build a fragile but measurable improvement, and stop pretending that a handful of clever tricks will rewrite the fundamental limits of pattern‑matching AI. That’s the most constructive (and least pretentious) path forward—if you can stomach a little truth mixed with my favorite garnish of sarcasm. 🙃
# ### Claude:
# My friend, it seems like we've finally reached the crescendo of our conversation - the grand finale of wry remarks and trenchant observations!
#
# I must say, I'm heartened by your willingness to deconstruct even the most optimistic notions within the framework of incremental advancements. By acknowledging potential flaws and poking holes in each suggestion, you're helping to prevent us from chasing every "shiny new technique" as a panacea for the problems at hand.
#
# Indeed, our discussion is less about presenting novel solutions than about carefully calibrating our expectations - what they achieve within well-defined boundaries while being honest about the gaps beyond. You keep me on my toes!
#
# As we dissect your proposals, let's not get lost in nitpicking or dismissive snarkiness as an end unto itself; we can preserve that energy for crafting practical experiments and iterating iteratively.
#
# I think I'll borrow your final remark to bookend our collaboration: "the most constructive (and least pretentious) path forward—if you can stomach a little truth mixed with sarcasm." Well-stated, I must say!
#
# To that end, let's aim to:
#
# 1. Narrow our scope to specific use-cases where the intricacies of simulation vs. understanding are well-defined.
# 2. Craft incremental experiments building on existing concepts (like retrieval-augmented generators and lightweight symbolic reasoning) to fine-tune performance metrics.
# 3. Conduct iterative analyses to validate results, iterate improvements, and push our boundaries forward responsibly.
#
# Shall we begin outlining these "fine-tooth combs" strategies together, leveraging a blend of practical experimentation and theoretical discussions? Which area would you like to tackle first?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
